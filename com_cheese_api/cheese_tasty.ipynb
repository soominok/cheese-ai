# %%
import pandas as pd
cheese = pd.read_csv("resources/data/cheese_data.csv")

# %%
cheese.head(5)
# Out:
#    Unnamed: 0  ranking cheese_id   brand       name country        matching  \
# 0           1        1        p1  벨지오이오소     부라타 치즈    이탈리아  채소, 발사믹식초, 견과류
# 1           2        2        p2    프란시아    모짜렐라 카우    이탈리아      토마토,바질,샐러드
# 2           3        3        p3     브렐렛    모짜렐라 카우    이탈리아      카프레제, 사퀘테리
# 3           4        4        p4    카스텔로  덴마크 브리 치즈     덴마크   빵, 꿀, 견과류, 와인
# 4           5        5        p5     브리미       보코치니    이탈리아       샐러드, 올리브유
#
#   texture types category    price                   content  \
# 0   후레쉬치즈  자연치즈      부라타  14,900원    버터처럼 부드러운 크림이 들어있는 생치즈
# 1   후레쉬치즈  자연치즈     모짜렐라   3,870원        신선하게 피어난 우유 그대로의 맛
# 2   후레쉬치즈  자연치즈     모짜렐라   3,990원  이탈리아 브리미에서 제조된 신선한 모짜렐라!
# 3   소프트치즈  자연치즈       브리   4,165원        부드럽게 녹아드는 숙성치즈의 매력
# 4   후레쉬치즈  자연치즈     모짜렐라   6,800원    새알을 빚어놓은 듯 깜찍한 미니 모짜렐라
#
#                                                  img
# 0  https://img-cf.kurly.com/shop/data/goods/15153...
# ...
