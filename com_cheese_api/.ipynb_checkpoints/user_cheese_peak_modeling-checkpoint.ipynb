# %%
import pandas as pd

users = pd.read_csv("resources/data/user_dataset.csv")

# %%
users.head(5)
# Out:
#    user_no  user_id user_gender  user_age  buy_count  cheese_rank  \
# 0        0  2391853           M        40          1          8.0
# 1        1  1799897           F        40          1          8.0
# 2        2  1614947           F        50          1         10.0
# 3        3  1614947           F        50          1         10.0
# 4        4  1614947           F        50          5         14.0
#
#    cheese_code cheese_id cheese_brand cheese_name cheese_texture cheese_types  \
# 0            8        p8         프란시아      리코타 치즈          후레쉬치즈         자연치즈
# 1            8        p8         프란시아      리코타 치즈          후레쉬치즈         자연치즈
# 2           10       p10         푸글리제        모짜렐라          후레쉬치즈         자연치즈
# 3           10       p10         푸글리제        모짜렐라          후레쉬치즈         자연치즈
# 4           15       p14          콜롬보        모짜렐라          후레쉬치즈         자연치즈
#
#   cheese_category cheese_one_price  gender  age_group  cheese_category_code  \
# 0             리코타           4,600원       0          3                     3
# 1             리코타           4,600원       1          3                     3
# 2            모짜렐라           5,500원       1          4                     1
# 3            모짜렐라           5,500원       1          4                     1
# 4            모짜렐라           4,900원       1          4                     1
#
#    cheese_texture_code brand  brand_code
# 0                    1  프란시아          15
# 1                    1  프란시아          15
# 2                    1  푸글리제          30
# 3                    1  푸글리제          30
# 4                    1   콜롬보          28

# %%
# user_X_train_set = user_X_train.drop('user_id', axis = 1)
users['cheese_id'] = users['cheese_id'].str.replace('p','')
users['cheese_one_price'] = users['cheese_one_price'].str.replace(',', '')
users['cheese_one_price'] = users['cheese_one_price'].str.replace('원', '')
users = users.astype({'cheese_one_price': int})

# user_X_trian_set = user_X_train_set.astype({'cheese_one_price': int})

# %%
users
# Out:
#        user_no  user_id user_gender  user_age  buy_count  cheese_rank  \
# 0            0  2391853           M        40          1          8.0
# 1            1  1799897           F        40          1          8.0
# 2            2  1614947           F        50          1         10.0
# 3            3  1614947           F        50          1         10.0
# 4            4  1614947           F        50          5         14.0
# ...        ...      ...         ...       ...        ...          ...
# 36868    36868  6159545           F        30          1         33.0
# 36869    36869  1942828           M        40          1         20.0
# 36870    36870  1942828           M        40          1         20.0
# 36871    36871  6284056           M        30          2         52.0
# 36872    36872  1306045           F        40          1          8.0
#
#        cheese_code cheese_id cheese_brand  cheese_name cheese_texture  \
# 0                8         8         프란시아       리코타 치즈          후레쉬치즈
# 1                8         8         프란시아       리코타 치즈          후레쉬치즈
# 2               10        10         푸글리제         모짜렐라          후레쉬치즈
# 3               10        10         푸글리제         모짜렐라          후레쉬치즈
# 4               15        14          콜롬보         모짜렐라          후레쉬치즈
# ...            ...       ...          ...          ...            ...
# 36868           39        33          샴피뇽      캄보졸라 치즈          소프트치즈
# 36869           22        20         카스텔로  덴마크 까망베르 치즈          소프트치즈
# 36870           22        20         카스텔로  덴마크 까망베르 치즈          소프트치즈
# 36871           62        52          브리미   락토스프리 모짜렐라          후레쉬치즈
# 36872            8         8         프란시아       리코타 치즈          후레쉬치즈
#
#       cheese_types cheese_category  cheese_one_price  gender  age_group  \
# 0             자연치즈             리코타              4600       0          3
# 1             자연치즈             리코타              4600       1          3
# 2             자연치즈            모짜렐라              5500       1          4
# 3             자연치즈            모짜렐라              5500       1          4
# 4             자연치즈            모짜렐라              4900       1          4
# ...            ...             ...               ...     ...        ...
# 36868         자연치즈            블루치즈              6400       1          2
# 36869         자연치즈            까망베르              4165       0          3
# 36870         자연치즈            까망베르              4165       0          3
# 36871         자연치즈            모짜렐라              5700       0          2
# 36872         자연치즈             리코타              4600       1          3
#
#        cheese_category_code  cheese_texture_code brand  brand_code
# 0                         3                    1  프란시아          15
# 1                         3                    1  프란시아          15
# 2                         1                    1  푸글리제          30
# 3                         1                    1  푸글리제          30
# 4                         1                    1   콜롬보          28
# ...                     ...                  ...   ...         ...
# 36868                     2                    4   샴피뇽          18
# 36869                     7                    4  카스텔로          32
# 36870                     7                    4  카스텔로          32
# 36871                     1                    1   브리미          34
# 36872                     3                    1  프란시아          15
#
# [36873 rows x 20 columns]

# %% [markdown]
# ## 히스토그램

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axes = plt.subplots(2, 2, figsize=(7,7), sharex=True)
sns.distplot(users["user_age"], color="red", ax=axes[0,0])
sns.distplot(users["cheese_code"], color="orange", ax=axes[0,1])
sns.distplot(users["cheese_category_code"], color = "yellow", ax=axes[1,0])
sns.distplot(users["brand_code"], color = "green", ax=axes[1,1])
# sns.distplot(user_data["cheese_texture_code"], color="blue", ax=axes[0,2])
# sns.distplot(user_data["cheese_one_price"], color = "purple", ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='brand_code'>

# %%
users["user_age"].value_counts()
# Out:
# 30    15514
# 40    14041
# 20     3514
# 50     3106
# 60      523
# 70       88
# 10       86
# 80        1
# Name: user_age, dtype: int64

# %%
users["cheese_code"].value_counts()
# Out:
# 2     5663
# 1     4239
# 5     2933
# 3     2823
# 7     2045
#       ...
# 80       6
# 78       5
# 79       5
# 85       3
# 82       2
# Name: cheese_code, Length: 69, dtype: int64

# %% [markdown]
# ## Peak 값 뽑기

# %%
users_top_age = users[(users["user_age"] == 30) | (users["user_age"] == 40) | (users["user_age"] == 20) | (users["user_age"] == 50)]

# %%
# users_top_age = users[(users["user_age"] == 30) | (users["user_age"] == 40)]

# %%
users_top_age["user_age"].value_counts()
# Out:
# 30    15514
# 40    14041
# 20     3514
# 50     3106
# Name: user_age, dtype: int64

# %%
users_top_age.value_counts(users_top_age["cheese_code"].values, sort=True)
# Out:
# 2     5554
# 1     4182
# 5     2882
# 3     2766
# 7     1992
#       ...
# 80       6
# 79       5
# 78       4
# 85       3
# 82       2
# Length: 69, dtype: int64

# %%
users_top_age_cheese = users_top_age[(users_top_age["cheese_code"] <= 25)]

# %%
users_top_age_cheese
# Out:
#        user_no  user_id user_gender  user_age  buy_count  cheese_rank  \
# 0            0  2391853           M        40          1          8.0
# 1            1  1799897           F        40          1          8.0
# 2            2  1614947           F        50          1         10.0
# 3            3  1614947           F        50          1         10.0
# 4            4  1614947           F        50          5         14.0
# ...        ...      ...         ...       ...        ...          ...
# 36864    36864  1743462           F        40          1          6.0
# 36865    36865    39553           F        40          1          6.0
# 36869    36869  1942828           M        40          1         20.0
# 36870    36870  1942828           M        40          1         20.0
# 36872    36872  1306045           F        40          1          8.0
#
#        cheese_code cheese_id cheese_brand    cheese_name cheese_texture  \
# 0                8         8         프란시아         리코타 치즈          후레쉬치즈
# 1                8         8         프란시아         리코타 치즈          후레쉬치즈
# 2               10        10         푸글리제           모짜렐라          후레쉬치즈
# 3               10        10         푸글리제           모짜렐라          후레쉬치즈
# 4               15        14          콜롬보           모짜렐라          후레쉬치즈
# ...            ...       ...          ...            ...            ...
# 36864            6         6         무르젤라  이탈리아 부라타 120g          후레쉬치즈
# 36865            6         6         무르젤라  이탈리아 부라타 120g          후레쉬치즈
# 36869           22        20         카스텔로    덴마크 까망베르 치즈          소프트치즈
# 36870           22        20         카스텔로    덴마크 까망베르 치즈          소프트치즈
# 36872            8         8         프란시아         리코타 치즈          후레쉬치즈
#
#       cheese_types cheese_category  cheese_one_price  gender  age_group  \
# 0             자연치즈             리코타              4600       0          3
# 1             자연치즈             리코타              4600       1          3
# 2             자연치즈            모짜렐라              5500       1          4
# 3             자연치즈            모짜렐라              5500       1          4
# 4             자연치즈            모짜렐라              4900       1          4
# ...            ...             ...               ...     ...        ...
# 36864         자연치즈             부라타              6600       1          3
# 36865         자연치즈             부라타              6600       1          3
# 36869         자연치즈            까망베르              4165       0          3
# 36870         자연치즈            까망베르              4165       0          3
# 36872         자연치즈             리코타              4600       1          3
#
#        cheese_category_code  cheese_texture_code brand  brand_code
# 0                         3                    1  프란시아          15
# 1                         3                    1  프란시아          15
# 2                         1                    1  푸글리제          30
# 3                         1                    1  푸글리제          30
# 4                         1                    1   콜롬보          28
# ...                     ...                  ...   ...         ...
# 36864                    11                    1  무르젤라          40
# 36865                    11                    1  무르젤라          40
# 36869                     7                    4  카스텔로          32
# 36870                     7                    4  카스텔로          32
# 36872                     3                    1  프란시아          15
#
# [30187 rows x 20 columns]

# %% [markdown]
# ### 히스토그램

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axes = plt.subplots(2, 2, figsize=(7,7), sharex=True)
sns.distplot(users_top_age_cheese["user_age"], color="red", ax=axes[0,0])
sns.distplot(users_top_age_cheese["cheese_code"], color="orange", ax=axes[0,1])
sns.distplot(users_top_age_cheese["cheese_category_code"], color = "yellow", ax=axes[1,0])
sns.distplot(users_top_age_cheese["brand_code"], color = "green", ax=axes[1,1])
# sns.distplot(user_data["cheese_texture_code"], color="blue", ax=axes[0,2])
# sns.distplot(user_data["cheese_one_price"], color = "purple", ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='brand_code'>

# %% [markdown]
# ## train, test 데이터 셋 만들기

# %%
from sklearn.model_selection import train_test_split

X_user_top = users_top_age_cheese[['user_age', 'gender', 'buy_count', 'cheese_rank', 'age_group', 'cheese_texture_code', 'brand_code', 'cheese_one_price']]
y_user_top = users_top_age_cheese[['cheese_category_code']]

X_user_train, X_user_test, y_user_train, y_user_test = train_test_split(X_user_top, y_user_top, test_size = 0.3, random_state = 32)

# %%
X_user_train.head(5)
# Out:
#        user_age  gender  buy_count  cheese_rank  age_group  \
# 13141        30       1          3          5.0          2
# 16907        30       1          1         11.0          2
# 29927        30       1          1          2.0          2
# 19100        30       1          1         13.0          2
# 14336        30       0          3         14.0          2
#
#        cheese_texture_code  brand_code  cheese_one_price
# 13141                    1          34              6800
# 16907                    2          41              5500
# 29927                    1          15              3870
# 19100                    1           5              3900
# 14336                    1          28              4900

# %%
y_user_train.head(5)
# Out:
#        cheese_category_code
# 13141                     1
# 16907                    10
# 29927                     1
# 19100                     1
# 14336                     1

# %% [markdown]
# ## 표준화

# %%
# std 바꿔서 fitting

import sklearn.svm as svm
import sklearn.metrics as mt
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.preprocessing import StandardScaler

# 표준화
std = StandardScaler()
# std.fit(X_train)

X_user_train_std = std.fit_transform(X_user_train)
X_user_test_std = std.transform(X_user_test)
print(X_user_train_std)
# Out:
# [[-0.55628505  0.42742647  0.19281057 ... -0.39545243  1.259723
#   -0.00595574]
#  [-0.55628505  0.42742647 -0.26905173 ...  0.75092016  1.90992899
#   -0.33689201]
#  [-0.55628505  0.42742647 -0.26905173 ... -0.39545243 -0.50512183
#   -0.75183517]
#  ...
#  [-0.55628505 -2.33958372 -0.26905173 ... -0.39545243  1.259723
#   -0.00595574]
#  [-0.55628505  0.42742647 -0.26905173 ... -0.39545243  0.70240358
#    0.00931824]
#  [ 0.71266703 -2.33958372 -0.03812058 ... -0.39545243 -0.78378154
#   -0.72128721]]

# %%
# # std 바꿔서 fitting

# import sklearn.svm as svm
# import sklearn.metrics as mt
# from sklearn.model_selection import cross_val_score, cross_validate
# from sklearn.preprocessing import StandardScaler

# # 표준화
# std = StandardScaler()
# # std.fit(X_train)

# X_user_train_sample_std = std.fit_transform(X_user_train_sample)
# X_user_test_sample_std = std.transform(X_user_test_sample)
# print(X_user_train_sample_std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-868a8483fa08> in <module>
#      10 # std.fit(X_train)
#      11
# ---> 12 X_user_train_sample_std = std.fit_transform(X_user_train_sample)
#      13 X_user_test_sample_std = std.transform(X_user_test_sample)
#      14 print(X_user_train_sample_std)
#
# NameError: name 'X_user_train_sample' is not defined

# %% [markdown]
# ## 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

ns = MinMaxScaler()
ns.fit(X_user_train)

X_user_train_ns = ns.transform(X_user_train)
X_user_test_ns = ns.transform(X_user_test)
print(X_user_train_ns)
# Out:
# [[0.33333333 1.         0.01257862 ... 0.         0.80487805 0.24355777]
#  [0.33333333 1.         0.         ... 0.33333333 0.97560976 0.1354946 ]
#  [0.33333333 1.         0.         ... 0.         0.34146341 0.        ]
#  ...
#  [0.33333333 0.         0.         ... 0.         0.80487805 0.24355777]
#  [0.33333333 1.         0.         ... 0.         0.65853659 0.2485453 ]
#  [0.66666667 0.         0.00628931 ... 0.         0.26829268 0.00997506]]

# %%
# from sklearn.preprocessing import MinMaxScaler

# ns = MinMaxScaler()
# ns.fit(X_user_train_sample)

# X_user_train_sample_ns = ns.transform(X_user_train_sample)
# X_user_test_sample_ns = ns.transform(X_user_test_sample)
# print(X_user_train_sample_ns)

# %% [markdown]
# ## 케라스로 모델링 작업

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def build_model():
    model = Sequential()
    model.add(Dense(8, activation = 'tanh', input_dim=8))
    model.add(Dense(4, activation = 'tanh'))
    model.add(Dense(1, activation = 'softmax'))

    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
    # model.fit(X_user_train, y_user_train, epochs = 100, batch_size = 5, verbose = 0)
    return model


YourModel = KerasRegressor(build_fn = build_model, epochs = 100, batch_size = 3, verbose = 1)

kf = KFold(n_splits = 5)

results = cross_val_score(YourModel, X_user_train_std, y_user_train, cv = kf)
# Out:
# Epoch 1/100
# 5635/5635 [==============================] - 2s 402us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 2/100
# 5635/5635 [==============================] - 2s 418us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 3/100
# 5635/5635 [==============================] - 2s 422us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 4/100
# 5635/5635 [==============================] - 2s 439us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 5/100
# 5635/5635 [==============================] - 2s 444us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 6/100
# 5635/5635 [==============================] - 2s 428us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 7/100
# 5635/5635 [==============================] - 2s 433us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 8/100
# 5635/5635 [==============================] - 2s 417us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 9/100
# 5635/5635 [==============================] - 2s 431us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 10/100
# 5635/5635 [==============================] - 2s 437us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 11/100
# 5635/5635 [==============================] - 2s 441us/step - loss: 0.0000e+00 - accuracy: 0.5401
# Epoch 12/100
# 3477/5635 [=================>............] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.5417

# %%
# from keras.models import Sequential
# from keras.layers import Dense, Activation
# from keras.layers import Dropout

# model = Sequential()
# model.add(Dense(16, activation = 'tanh', input_dim=8))
# model.add(Dropout(0.5))
# model.add(Dense(8, activation = 'tanh'))
# model.add(Dropout(0.2))
# model.add(Dense(4, activation = 'tanh'))
# model.add(Dropout(0.2))
# model.add(Dense(2, activation = 'relu')) 
# model.add(Dropout(0.2))
# model.add(Dense(1, activation = 'sigmoid'))
# model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy')

# model.summary()
# model.fit(X_user_train, y_user_train, epochs = 100, batch_size = 5, verbose = 1, validata_data=(X_user_test, y_user_test))

# print("Test Loss = ", model.evaluate(X_user_test, y_user_test))

# %% [markdown]
# ## OHE로 다시 모델링 학습하기

# %%
# 전체 데이터를 학습시켰을 때 loss값이 0.000e+00과 accuracy가 0.4866으로 나왔음

# (원인 해석)
# 데이터가 너무 편향되어 있어서 loss값이 0.000e+00이 나오는 것
# accuracy도 0.5가 안되는 것을 보면 dense가 너무 작음 - 더 정확도를 높여야 함

# https://www.it-swarm-ko.tech/ko/python/valueerror-%EB%AA%A8%EC%96%91-%EC%97%86%EC%9D%8C-1-%EB%B0%8F-%EC%97%86%EC%9D%8C-3%EC%9D%B4-%ED%98%B8%ED%99%98%EB%90%98%EC%A7%80-%EC%95%8A%EC%8A%B5%EB%8B%88%EB%8B%A4/816831714/
# peak값을 추출하여 봤는데도 y값을 원핫인코딩 해줘야할 것 같음
# OHE로 해서 y값을 다시 시도해보기

# %%
import pandas as pd

y_user_train_ohe = pd.get_dummies(y_user_train['cheese_category_code'])
y_user_test_ohe = pd.get_dummies(y_user_test['cheese_category_code'])

# %%
y_user_train_ohe.head(3)
y_user_train_ohe.isnull().sum()
# Out:
# 1     0
# 3     0
# 4     0
# 7     0
# 8     0
# 10    0
# 11    0
# dtype: int64

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def build_model():
    model = Sequential()
    model.add(Dense(8, activation = 'tanh', input_dim=8))
    model.add(Dense(4, activation = 'tanh'))
    model.add(Dense(1, activation = 'softmax'))

    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
    # model.fit(X_user_train, y_user_train, epochs = 100, batch_size = 5, verbose = 0)
    return model


YourModel = KerasRegressor(build_fn = build_model, epochs = 100, batch_size = 3, verbose = 1)

kf = KFold(n_splits = 5)

results = cross_val_score(YourModel, X_user_train_std, y_user_train_ohe, cv = kf)
# Out:
# Epoch 1/100
# Epoch 1/100
# Epoch 1/100
# Epoch 1/100
# /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 823, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 697, in _initialize
#     *args, **kwds))
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2855, in _get_concrete_function_internal_garbage_collected
#     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3075, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 600, in wrapped_fn
#     return weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 973, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:806 train_function  *
#         return step_function(self, iterator)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:789 run_step  **
#         outputs = model.train_step(data)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 7) and (None, 1) are incompatible
#
#
#   FitFailedWarning)
# /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 823, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 697, in _initialize
#     *args, **kwds))
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2855, in _get_concrete_function_internal_garbage_collected
#     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3075, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 600, in wrapped_fn
#     return weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 973, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:806 train_function  *
#         return step_function(self, iterator)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:789 run_step  **
#         outputs = model.train_step(data)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 7) and (None, 1) are incompatible
#
#
#   FitFailedWarning)
# /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 823, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 697, in _initialize
#     *args, **kwds))
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2855, in _get_concrete_function_internal_garbage_collected
#     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3075, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 600, in wrapped_fn
#     return weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 973, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:806 train_function  *
#         return step_function(self, iterator)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:789 run_step  **
#         outputs = model.train_step(data)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 7) and (None, 1) are incompatible
#
#
#   FitFailedWarning)
# /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 823, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 697, in _initialize
#     *args, **kwds))
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2855, in _get_concrete_function_internal_garbage_collected
#     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3075, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 600, in wrapped_fn
#     return weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 973, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:806 train_function  *
#         return step_function(self, iterator)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:789 run_step  **
#         outputs = model.train_step(data)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 7) and (None, 1) are incompatible
#
#
#   FitFailedWarning)
# Epoch 1/100
# /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 823, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 697, in _initialize
#     *args, **kwds))
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2855, in _get_concrete_function_internal_garbage_collected
#     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 3075, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 600, in wrapped_fn
#     return weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py", line 973, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:806 train_function  *
#         return step_function(self, iterator)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:789 run_step  **
#         outputs = model.train_step(data)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bitai/anaconda3/envs/cheese-ai/lib/python3.7/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 7) and (None, 1) are incompatible
#
#
#   FitFailedWarning)
