# %%
import pandas as pd

users = pd.read_csv("resources/data/user_dataset.csv")

# %%
users.head(5)
# Out:
#    user_no  user_id user_gender  user_age  buy_count  cheese_rank  \
# 0        0  2391853           M        40          1          8.0
# 1        1  1799897           F        40          1          8.0
# 2        2  1614947           F        50          1         10.0
# 3        3  1614947           F        50          1         10.0
# 4        4  1614947           F        50          5         14.0
#
#    cheese_code cheese_id cheese_brand cheese_name cheese_texture cheese_types  \
# 0            8        p8         프란시아      리코타 치즈          후레쉬치즈         자연치즈
# 1            8        p8         프란시아      리코타 치즈          후레쉬치즈         자연치즈
# 2           10       p10         푸글리제        모짜렐라          후레쉬치즈         자연치즈
# 3           10       p10         푸글리제        모짜렐라          후레쉬치즈         자연치즈
# 4           15       p14          콜롬보        모짜렐라          후레쉬치즈         자연치즈
#
#   cheese_category cheese_one_price  gender  age_group  cheese_category_code  \
# 0             리코타           4,600원       0          3                     3
# 1             리코타           4,600원       1          3                     3
# 2            모짜렐라           5,500원       1          4                     1
# 3            모짜렐라           5,500원       1          4                     1
# 4            모짜렐라           4,900원       1          4                     1
#
#    cheese_texture_code brand  brand_code
# 0                    1  프란시아          15
# 1                    1  프란시아          15
# 2                    1  푸글리제          30
# 3                    1  푸글리제          30
# 4                    1   콜롬보          28

# %%
user_X_train = pd.read_csv("resources/data/user_train.csv")
user_X_train.head(5)
# Out:
#    user_no  user_id user_gender  user_age  buy_count  cheese_rank  \
# 0     3312  1751881           F        30          2          2.0
# 1    21971  1835210           F        30          2          2.0
# 2     2347  5824726           F        50          1         15.0
# 3    18459  1752218           M        40          3          2.0
# 4     8768  2034072           F        40          1         17.0
#
#    cheese_code cheese_id cheese_brand cheese_name cheese_texture cheese_types  \
# 0            2        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 1            2        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 2           16       p15          콜롬보         리코타          후레쉬치즈         자연치즈
# 3            2        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 4           18       p17         프란시아    모짜렐라 부팔라          후레쉬치즈         자연치즈
#
#   cheese_category cheese_one_price  gender  age_group  cheese_category_code  \
# 0            모짜렐라           3,870원       1          2                     1
# 1            모짜렐라           3,870원       1          2                     1
# 2             리코타           6,860원       1          4                     3
# 3            모짜렐라           3,870원       0          3                     1
# 4            모짜렐라           6,240원       1          3                     1
#
#    cheese_texture_code brand  brand_code
# 0                    1  프란시아          15
# 1                    1  프란시아          15
# 2                    1   콜롬보          28
# 3                    1  프란시아          15
# 4                    1  프란시아          15

# %%
user_X_train_set = user_X_train.drop('user_id', axis = 1)
user_X_train_set['cheese_one_price'] = user_X_train_set['cheese_one_price'].str.replace(',', '')
user_X_train_set['cheese_one_price'] = user_X_train_set['cheese_one_price'].str.replace('원', '')

user_X_trian_set = user_X_train_set.astype({'cheese_one_price': int})

# %%
user_X_train_set.head(5)
# Out:
#    user_no user_gender  user_age  buy_count  cheese_rank  cheese_code  \
# 0     3312           F        30          2          2.0            2
# 1    21971           F        30          2          2.0            2
# 2     2347           F        50          1         15.0           16
# 3    18459           M        40          3          2.0            2
# 4     8768           F        40          1         17.0           18
#
#   cheese_id cheese_brand cheese_name cheese_texture cheese_types  \
# 0        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 1        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 2       p15          콜롬보         리코타          후레쉬치즈         자연치즈
# 3        p2         프란시아     모짜렐라 카우          후레쉬치즈         자연치즈
# 4       p17         프란시아    모짜렐라 부팔라          후레쉬치즈         자연치즈
#
#   cheese_category cheese_one_price  gender  age_group  cheese_category_code  \
# 0            모짜렐라             3870       1          2                     1
# 1            모짜렐라             3870       1          2                     1
# 2             리코타             6860       1          4                     3
# 3            모짜렐라             3870       0          3                     1
# 4            모짜렐라             6240       1          3                     1
#
#    cheese_texture_code brand  brand_code
# 0                    1  프란시아          15
# 1                    1  프란시아          15
# 2                    1   콜롬보          28
# 3                    1  프란시아          15
# 4                    1  프란시아          15

# %% [markdown]
# ## 히스토그램

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axes = plt.subplots(2, 3, figsize=(7,7), sharex=True)
sns.distplot(user_data["user_age"], color="red", ax=axes[0,0])
sns.distplot(user_data["cheese_code"], color="orange", ax=axes[0,1])
sns.distplot(user_data["cheese_category_code"], color = "yellow", ax=axes[1,0])
sns.distplot(user_data["brand_code"], color = "green", ax=axes[1,1])
# sns.distplot(user_data["cheese_texture_code"], color="blue", ax=axes[0,2])
# sns.distplot(user_data["cheese_one_price"], color = "purple", ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='brand_code'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axes = plt.subplots(2, 3, figsize=(7,7), sharex=True)
sns.distplot(user_X_train_set["user_age"], color="red", ax=axes[0,0])
sns.distplot(user_X_train_set["cheese_code"], color="orange", ax=axes[0,1])
sns.distplot(user_X_train_set["cheese_category_code"], color = "yellow", ax=axes[1,0])
sns.distplot(user_X_train_set["brand_code"], color = "green", ax=axes[1,1])
# sns.distplot(user_X_train_set["cheese_texture_code"], color="blue", ax=axes[0,2])
# sns.distplot(user_X_train_set["cheese_one_price"], color = "purple", ax=axes[1,2])
# Out:
# <AxesSubplot:xlabel='brand_code'>

# %% [markdown]
# ## 데이터 변환

# %%
import numpy as np

user_data['log_cheese_code'] = np.log1p(user_data['cheese_code'])

f, ax = plt.subplots(1, 2, figsize = (10, 6),  sharex=True)

sns.distplot(user_data['cheese_code'], ax=axes[0,0])
sns.distplot(user_data['log_cheese_code'], ax=axes[0,1])
# Out:
# <AxesSubplot:xlabel='log_cheese_code'>

# %%
user_data['cheese_category_code'].corr(user_data['age_group'])
# Out:
# -0.02096866938420734
